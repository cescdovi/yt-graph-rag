# %%
from pydantic import BaseModel, Field
from typing import List, Literal, Optional
from uuid import uuid4
from typing import Union

class EntidadBase(BaseModel):
    """Información genérica de todas las entidades"""
    nombre: str = Field(..., description="Nombre que representa a la entidad")
    descripcion: str = Field(..., description="Descripción identificativa de la entidad")

class Persona(EntidadBase):
    """Información de una persona"""
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único de la persona usando la función uuid4 del módulo uuid")
    tipo: Literal['Persona']
    profesion: str = Field(..., description="Profesión u oficio de la persona")

class Empresa(EntidadBase):
    """Información de una empresa u organización"""
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único de la empresa usando la función uuid4 del módulo uuid")
    tipo: Literal['Empresa']
    industria: Optional[str] = Field(None, description="Sector o industria de la empresa")

class CentroEducativo(EntidadBase):
    """Información de un centro educativo"""
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único del centro educativo usando la función uuid4 del módulo uuid")
    tipo: Literal['CentroEducativo']
    localizacion: Optional[str] = Field(None, description="Ubicación o ciudad del centro educativo")

class Movimiento(EntidadBase):
    """Información de un movimiento o corriente de diseño/práctica"""
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único del movimiento usando la función uuid4 del módulo uuid")
    tipo: Literal['Movimiento']
    categoria: Optional[str] = Field(
        None,
        description="Corriente o estilo (ej. minimalista, impresionista, art déco, etc.)"
    )

class Producto(EntidadBase):
    """
    Modelo que representa una entidad de tipo “Producto” y sus posibles subtipos.
    
    - tipo: indica que se trata de un producto.
    - subtipo: especifica si es un material, una técnica, un tipo genérico u otro.
    """
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único del producto usando la función uuid4 del módulo uuid")
    tipo: Literal['Producto'] = Field(
        'Producto',
        description="Constante que identifica la entidad como un producto."
    )
    subtipo: Optional[Literal['material', 'técnica', 'tipo', 'otro']] = Field(
        None,
        description="Subcategoría del producto. Puede ser 'material', 'técnica', 'tipo' u 'otro'."
    )

class Entidades(BaseModel):
    """Contenedor de todas las entidades extraídas"""
    personas: List[Persona] = Field(default_factory=list)
    empresas: List[Empresa] = Field(default_factory=list)
    centros_educativos: List[CentroEducativo] = Field(default_factory=list)
    movimientos: List[Movimiento] = Field(default_factory=list)
    productos: List[Producto] = Field(default_factory=list)

################################################
class Relacion(BaseModel):
    id: str = Field(default_factory=lambda: str(uuid4()), description="Identificador único de la relación usando la función uuid4 del módulo uuid")
    entidad_origen: Union[Persona, Empresa, CentroEducativo, Movimiento, Producto]
    entidad_destino: Union[Persona, Empresa, CentroEducativo, Movimiento, Producto]
    descripcion_relacion: str = Field(..., description="explicación de por qué considera que la entidad origen y la entidad destino están relacionadas")
    fuerza_relacion: float = Field(..., description="puntuación numérica que indica la fuerza de la relación entre la entidad origen y la entidad destino")


class Relaciones(BaseModel):
    """Contenedor de todos los pares relacionados"""
    relaciones: List[Relacion] = Field(default_factory=list)


################################################
class OutputSchema(BaseModel):
    entidades: Entidades
    relaciones: Relaciones

# %%
Entidades
# Out:
# __main__.Entidades

# %%
print(Persona.model_json_schema())
# Out:
# {'description': 'Información de una persona', 'properties': {'nombre': {'description': 'Nombre que representa a la entidad', 'title': 'Nombre', 'type': 'string'}, 'descripcion': {'description': 'Descripción identificativa de la entidad', 'title': 'Descripcion', 'type': 'string'}, 'id': {'description': 'Identificador único de la persona usando la función uuid4 del módulo uuid', 'title': 'Id', 'type': 'string'}, 'tipo': {'const': 'Persona', 'title': 'Tipo', 'type': 'string'}, 'profesion': {'description': 'Profesión u oficio de la persona', 'title': 'Profesion', 'type': 'string'}}, 'required': ['nombre', 'descripcion', 'tipo', 'profesion'], 'title': 'Persona', 'type': 'object'}

# %%
Relacion.model_json_schema()
# Out:
# {'$defs': {'CentroEducativo': {'description': 'Información de un centro educativo',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del centro educativo usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'CentroEducativo', 'title': 'Tipo', 'type': 'string'},
#     'localizacion': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Ubicación o ciudad del centro educativo',
#      'title': 'Localizacion'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'CentroEducativo',
#    'type': 'object'},
#   'Empresa': {'description': 'Información de una empresa u organización',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único de la empresa usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Empresa', 'title': 'Tipo', 'type': 'string'},
#     'industria': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Sector o industria de la empresa',
#      'title': 'Industria'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'Empresa',
#    'type': 'object'},
#   'Movimiento': {'description': 'Información de un movimiento o corriente de diseño/práctica',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del movimiento usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Movimiento', 'title': 'Tipo', 'type': 'string'},
#     'categoria': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Corriente o estilo (ej. minimalista, impresionista, art déco, etc.)',
#      'title': 'Categoria'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'Movimiento',
#    'type': 'object'},
#   'Persona': {'description': 'Información de una persona',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único de la persona usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Persona', 'title': 'Tipo', 'type': 'string'},
#     'profesion': {'description': 'Profesión u oficio de la persona',
#      'title': 'Profesion',
#      'type': 'string'}},
#    'required': ['nombre', 'descripcion', 'tipo', 'profesion'],
#    'title': 'Persona',
#    'type': 'object'},
#   'Producto': {'description': 'Modelo que representa una entidad de tipo “Producto” y sus posibles subtipos.\n\n- tipo: indica que se trata de un producto.\n- subtipo: especifica si es un material, una técnica, un tipo genérico u otro.',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del producto usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Producto',
#      'default': 'Producto',
#      'description': 'Constante que identifica la entidad como un producto.',
#      'title': 'Tipo',
#      'type': 'string'},
#     'subtipo': {'anyOf': [{'enum': ['material', 'técnica', 'tipo', 'otro'],
#        'type': 'string'},
#       {'type': 'null'}],
#      'default': None,
#      'description': "Subcategoría del producto. Puede ser 'material', 'técnica', 'tipo' u 'otro'.",
#      'title': 'Subtipo'}},
#    'required': ['nombre', 'descripcion'],
#    'title': 'Producto',
#    'type': 'object'}},
#  'properties': {'id': {'description': 'Identificador único de la relación usando la función uuid4 del módulo uuid',
#    'title': 'Id',
#    'type': 'string'},
#   'entidad_origen': {'anyOf': [{'$ref': '#/$defs/Persona'},
#     {'$ref': '#/$defs/Empresa'},
#     {'$ref': '#/$defs/CentroEducativo'},
#     {'$ref': '#/$defs/Movimiento'},
#     {'$ref': '#/$defs/Producto'}],
#    'title': 'Entidad Origen'},
#   'entidad_destino': {'anyOf': [{'$ref': '#/$defs/Persona'},
#     {'$ref': '#/$defs/Empresa'},
#     {'$ref': '#/$defs/CentroEducativo'},
#     {'$ref': '#/$defs/Movimiento'},
#     {'$ref': '#/$defs/Producto'}],
#    'title': 'Entidad Destino'},
#   'descripcion_relacion': {'description': 'explicación de por qué considera que la entidad origen y la entidad destino están relacionadas',
#    'title': 'Descripcion Relacion',
#    'type': 'string'},
#   'fuerza_relacion': {'description': 'puntuación numérica que indica la fuerza de la relación entre la entidad origen y la entidad destino',
#    'title': 'Fuerza Relacion',
#    'type': 'number'}},
#  'required': ['entidad_origen',
#   'entidad_destino',
#   'descripcion_relacion',
#   'fuerza_relacion'],
#  'title': 'Relacion',
#  'type': 'object'}

# %%
OutputSchema.model_json_schema()
# Out:
# {'$defs': {'CentroEducativo': {'description': 'Información de un centro educativo',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del centro educativo usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'CentroEducativo', 'title': 'Tipo', 'type': 'string'},
#     'localizacion': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Ubicación o ciudad del centro educativo',
#      'title': 'Localizacion'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'CentroEducativo',
#    'type': 'object'},
#   'Empresa': {'description': 'Información de una empresa u organización',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único de la empresa usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Empresa', 'title': 'Tipo', 'type': 'string'},
#     'industria': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Sector o industria de la empresa',
#      'title': 'Industria'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'Empresa',
#    'type': 'object'},
#   'Entidades': {'description': 'Contenedor de todas las entidades extraídas',
#    'properties': {'personas': {'items': {'$ref': '#/$defs/Persona'},
#      'title': 'Personas',
#      'type': 'array'},
#     'empresas': {'items': {'$ref': '#/$defs/Empresa'},
#      'title': 'Empresas',
#      'type': 'array'},
#     'centros_educativos': {'items': {'$ref': '#/$defs/CentroEducativo'},
#      'title': 'Centros Educativos',
#      'type': 'array'},
#     'movimientos': {'items': {'$ref': '#/$defs/Movimiento'},
#      'title': 'Movimientos',
#      'type': 'array'},
#     'productos': {'items': {'$ref': '#/$defs/Producto'},
#      'title': 'Productos',
#      'type': 'array'}},
#    'title': 'Entidades',
#    'type': 'object'},
#   'Movimiento': {'description': 'Información de un movimiento o corriente de diseño/práctica',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del movimiento usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Movimiento', 'title': 'Tipo', 'type': 'string'},
#     'categoria': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': None,
#      'description': 'Corriente o estilo (ej. minimalista, impresionista, art déco, etc.)',
#      'title': 'Categoria'}},
#    'required': ['nombre', 'descripcion', 'tipo'],
#    'title': 'Movimiento',
#    'type': 'object'},
#   'Persona': {'description': 'Información de una persona',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único de la persona usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Persona', 'title': 'Tipo', 'type': 'string'},
#     'profesion': {'description': 'Profesión u oficio de la persona',
#      'title': 'Profesion',
#      'type': 'string'}},
#    'required': ['nombre', 'descripcion', 'tipo', 'profesion'],
#    'title': 'Persona',
#    'type': 'object'},
#   'Producto': {'description': 'Modelo que representa una entidad de tipo “Producto” y sus posibles subtipos.\n\n- tipo: indica que se trata de un producto.\n- subtipo: especifica si es un material, una técnica, un tipo genérico u otro.',
#    'properties': {'nombre': {'description': 'Nombre que representa a la entidad',
#      'title': 'Nombre',
#      'type': 'string'},
#     'descripcion': {'description': 'Descripción identificativa de la entidad',
#      'title': 'Descripcion',
#      'type': 'string'},
#     'id': {'description': 'Identificador único del producto usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'tipo': {'const': 'Producto',
#      'default': 'Producto',
#      'description': 'Constante que identifica la entidad como un producto.',
#      'title': 'Tipo',
#      'type': 'string'},
#     'subtipo': {'anyOf': [{'enum': ['material', 'técnica', 'tipo', 'otro'],
#        'type': 'string'},
#       {'type': 'null'}],
#      'default': None,
#      'description': "Subcategoría del producto. Puede ser 'material', 'técnica', 'tipo' u 'otro'.",
#      'title': 'Subtipo'}},
#    'required': ['nombre', 'descripcion'],
#    'title': 'Producto',
#    'type': 'object'},
#   'Relacion': {'properties': {'id': {'description': 'Identificador único de la relación usando la función uuid4 del módulo uuid',
#      'title': 'Id',
#      'type': 'string'},
#     'entidad_origen': {'anyOf': [{'$ref': '#/$defs/Persona'},
#       {'$ref': '#/$defs/Empresa'},
#       {'$ref': '#/$defs/CentroEducativo'},
#       {'$ref': '#/$defs/Movimiento'},
#       {'$ref': '#/$defs/Producto'}],
#      'title': 'Entidad Origen'},
#     'entidad_destino': {'anyOf': [{'$ref': '#/$defs/Persona'},
#       {'$ref': '#/$defs/Empresa'},
#       {'$ref': '#/$defs/CentroEducativo'},
#       {'$ref': '#/$defs/Movimiento'},
#       {'$ref': '#/$defs/Producto'}],
#      'title': 'Entidad Destino'},
#     'descripcion_relacion': {'description': 'explicación de por qué considera que la entidad origen y la entidad destino están relacionadas',
#      'title': 'Descripcion Relacion',
#      'type': 'string'},
#     'fuerza_relacion': {'description': 'puntuación numérica que indica la fuerza de la relación entre la entidad origen y la entidad destino',
#      'title': 'Fuerza Relacion',
#      'type': 'number'}},
#    'required': ['entidad_origen',
#     'entidad_destino',
#     'descripcion_relacion',
#     'fuerza_relacion'],
#    'title': 'Relacion',
#    'type': 'object'},
#   'Relaciones': {'description': 'Contenedor de todos los pares relacionados',
#    'properties': {'relaciones': {'items': {'$ref': '#/$defs/Relacion'},
#      'title': 'Relaciones',
#      'type': 'array'}},
#    'title': 'Relaciones',
#    'type': 'object'}},
#  'properties': {'entidades': {'$ref': '#/$defs/Entidades'},
#   'relaciones': {'$ref': '#/$defs/Relaciones'}},
#  'required': ['entidades', 'relaciones'],
#  'title': 'OutputSchema',
#  'type': 'object'}

# %%
entdades = Entidades.model_json_schema()

# %%
import json
print(json.dumps(entdades, indent=4, ensure_ascii=False))
# Out:
# {
#     "$defs": {
#         "CentroEducativo": {
#             "description": "Información de un centro educativo",
#             "properties": {
#                 "nombre": {
#                     "description": "Nombre que representa a la entidad",
#                     "title": "Nombre",
#                     "type": "string"
#                 },
#                 "descripcion": {
#                     "description": "Descripción identificativa de la entidad",
#                     "title": "Descripcion",
#                     "type": "string"
#                 },
#                 "id": {
#                     "description": "Identificador único del centro educativo usando la función uuid4 del módulo uuid",
#                     "title": "Id",
#                     "type": "string"
#                 },
#                 "tipo": {
#                     "const": "CentroEducativo",
#                     "title": "Tipo",
#                     "type": "string"
#                 },
#                 "localizacion": {
#                     "anyOf": [
#                         {
#                             "type": "string"
#                         },
#                         {
#                             "type": "null"
#                         }
#                     ],
#                     "default": null,
#                     "description": "Ubicación o ciudad del centro educativo",
#                     "title": "Localizacion"
#                 }
#             },
#             "required": [
#                 "nombre",
#                 "descripcion",
#                 "tipo"
#             ],
#             "title": "CentroEducativo",
#             "type": "object"
#         },
#         "Empresa": {
#             "description": "Información de una empresa u organización",
#             "properties": {
#                 "nombre": {
#                     "description": "Nombre que representa a la entidad",
#                     "title": "Nombre",
#                     "type": "string"
#                 },
#                 "descripcion": {
#                     "description": "Descripción identificativa de la entidad",
#                     "title": "Descripcion",
#                     "type": "string"
#                 },
#                 "id": {
#                     "description": "Identificador único de la empresa usando la función uuid4 del módulo uuid",
#                     "title": "Id",
#                     "type": "string"
#                 },
#                 "tipo": {
#                     "const": "Empresa",
#                     "title": "Tipo",
#                     "type": "string"
#                 },
#                 "industria": {
#                     "anyOf": [
#                         {
#                             "type": "string"
#                         },
#                         {
#                             "type": "null"
#                         }
#                     ],
#                     "default": null,
#                     "description": "Sector o industria de la empresa",
#                     "title": "Industria"
#                 }
#             },
#             "required": [
#                 "nombre",
#                 "descripcion",
#                 "tipo"
#             ],
#             "title": "Empresa",
#             "type": "object"
#         },
#         "Movimiento": {
#             "description": "Información de un movimiento o corriente de diseño/práctica",
#             "properties": {
#                 "nombre": {
#                     "description": "Nombre que representa a la entidad",
#                     "title": "Nombre",
#                     "type": "string"
#                 },
#                 "descripcion": {
#                     "description": "Descripción identificativa de la entidad",
#                     "title": "Descripcion",
#                     "type": "string"
#                 },
#                 "id": {
#                     "description": "Identificador único del movimiento usando la función uuid4 del módulo uuid",
#                     "title": "Id",
#                     "type": "string"
#                 },
#                 "tipo": {
#                     "const": "Movimiento",
#                     "title": "Tipo",
#                     "type": "string"
#                 },
#                 "categoria": {
#                     "anyOf": [
#                         {
#                             "type": "string"
#                         },
#                         {
#                             "type": "null"
#                         }
#                     ],
#                     "default": null,
#                     "description": "Corriente o estilo (ej. minimalista, impresionista, art déco, etc.)",
#                     "title": "Categoria"
#                 }
#             },
#             "required": [
#                 "nombre",
#                 "descripcion",
#                 "tipo"
#             ],
#             "title": "Movimiento",
#             "type": "object"
#         },
#         "Persona": {
#             "description": "Información de una persona",
#             "properties": {
#                 "nombre": {
#                     "description": "Nombre que representa a la entidad",
#                     "title": "Nombre",
#                     "type": "string"
#                 },
#                 "descripcion": {
#                     "description": "Descripción identificativa de la entidad",
#                     "title": "Descripcion",
#                     "type": "string"
#                 },
#                 "id": {
#                     "description": "Identificador único de la persona usando la función uuid4 del módulo uuid",
#                     "title": "Id",
#                     "type": "string"
#                 },
#                 "tipo": {
#                     "const": "Persona",
#                     "title": "Tipo",
#                     "type": "string"
#                 },
#                 "profesion": {
#                     "description": "Profesión u oficio de la persona",
#                     "title": "Profesion",
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "nombre",
#                 "descripcion",
#                 "tipo",
#                 "profesion"
#             ],
#             "title": "Persona",
#             "type": "object"
#         },
#         "Producto": {
#             "description": "Modelo que representa una entidad de tipo “Producto” y sus posibles subtipos.\n\n- tipo: indica que se trata de un producto.\n- subtipo: especifica si es un material, una técnica, un tipo genérico u otro.",
#             "properties": {
#                 "nombre": {
#                     "description": "Nombre que representa a la entidad",
#                     "title": "Nombre",
#                     "type": "string"
#                 },
#                 "descripcion": {
#                     "description": "Descripción identificativa de la entidad",
#                     "title": "Descripcion",
#                     "type": "string"
#                 },
#                 "id": {
#                     "description": "Identificador único del producto usando la función uuid4 del módulo uuid",
#                     "title": "Id",
#                     "type": "string"
#                 },
#                 "tipo": {
#                     "const": "Producto",
#                     "default": "Producto",
#                     "description": "Constante que identifica la entidad como un producto.",
#                     "title": "Tipo",
#                     "type": "string"
#                 },
#                 "subtipo": {
#                     "anyOf": [
#                         {
#                             "enum": [
#                                 "material",
#                                 "técnica",
#                                 "tipo",
#                                 "otro"
#                             ],
#                             "type": "string"
#                         },
#                         {
#                             "type": "null"
#                         }
#                     ],
#                     "default": null,
#                     "description": "Subcategoría del producto. Puede ser 'material', 'técnica', 'tipo' u 'otro'.",
#                     "title": "Subtipo"
#                 }
#             },
#             "required": [
#                 "nombre",
#                 "descripcion"
#             ],
#             "title": "Producto",
#             "type": "object"
#         }
#     },
#     "description": "Contenedor de todas las entidades extraídas",
#     "properties": {
#         "personas": {
#             "items": {
#                 "$ref": "#/$defs/Persona"
#             },
#             "title": "Personas",
#             "type": "array"
#         },
#         "empresas": {
#             "items": {
#                 "$ref": "#/$defs/Empresa"
#             },
#             "title": "Empresas",
#             "type": "array"
#         },
#         "centros_educativos": {
#             "items": {
#                 "$ref": "#/$defs/CentroEducativo"
#             },
#             "title": "Centros Educativos",
#             "type": "array"
#         },
#         "movimientos": {
#             "items": {
#                 "$ref": "#/$defs/Movimiento"
#             },
#             "title": "Movimientos",
#             "type": "array"
#         },
#         "productos": {
#             "items": {
#                 "$ref": "#/$defs/Producto"
#             },
#             "title": "Productos",
#             "type": "array"
#         }
#     },
#     "title": "Entidades",
#     "type": "object"
# }
